# %%
# !pip install trl

# %%
# from kaggle_secrets import UserSecretsClient
# user_secrets = UserSecretsClient()
# github_token = user_secrets.get_secret("github_token_tlab")

# username = "sadwat0"
# repo = "tlab-assignment"

# !git clone https://github.com/sadwat0/tlab-assignment.git
# Out:
# Cloning into 'tlab-assignment'...
# remote: Enumerating objects: 56, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 56 (delta 25), reused 49 (delta 18), pack-reused 0 (from 0)
# Receiving objects: 100% (56/56), 11.70 KiB | 2.34 MiB/s, done.
# Resolving deltas: 100% (25/25), done.

# %% [markdown]
# Я не добавил парсинг аргументов всего config, так что придется сделать так (это нужно убрать либо добавить wandb_api_key в kaggle secrets):

# %%
# !head tlab-assignment/src/config.py 

# !sed -i 's/WANDB_LOGGING: bool = False/WANDB_LOGGING: bool = True/g' tlab-assignment/src/config.py
# !sed -i 's/IS_ON_KAGGLE: bool = False/IS_ON_KAGGLE: bool = True/g' tlab-assignment/src/config.py

# !head tlab-assignment/src/config.py

# %% [markdown]
# Не забудьте добавить secret с именем wandb_api_key если это включили.

# %% [markdown]
# ## Обучение reward model

# %%
# !python tlab-assignment/src/reward_model_trainer.py --output_model_dir=./trained_reward_model
# Out:
# 2025-02-01 09:51:01.005444: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-01 09:51:01.194654: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-01 09:51:01.249568: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: sadwat. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# ...

# %%
# !zip -r "trained_reward_model.zip" "./trained_reward_model"
# Out:
#   adding: trained_reward_model/ (stored 0%)
#   adding: trained_reward_model/checkpoint-868/ (stored 0%)
#   adding: trained_reward_model/checkpoint-868/vocab.json (deflated 59%)
#   adding: trained_reward_model/checkpoint-868/special_tokens_map.json (deflated 76%)
#   adding: trained_reward_model/checkpoint-868/trainer_state.json (deflated 76%)
#   adding: trained_reward_model/checkpoint-868/scheduler.pt (deflated 55%)
#   adding: trained_reward_model/checkpoint-868/tokenizer_config.json (deflated 83%)
#   adding: trained_reward_model/checkpoint-868/rng_state.pth (deflated 25%)
#   adding: trained_reward_model/checkpoint-868/merges.txt (deflated 55%)
#   adding: trained_reward_model/checkpoint-868/optimizer.pt (deflated 12%)
#   adding: trained_reward_model/checkpoint-868/model.safetensors (deflated 9%)
#   adding: trained_reward_model/checkpoint-868/training_args.bin (deflated 51%)
#   adding: trained_reward_model/checkpoint-868/config.json (deflated 50%)
# ...

# %% [markdown]
# ## REINFORCE w/ baseline

# %%
# !python tlab-assignment/src/reinforce.py --reward_model_path=./trained_reward_model --output_model_dir=./reinforce_with_baseline_v2
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: sadwat. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.19.1
# wandb: Run data is saved locally in /kaggle/working/tlab-assignment/wandb/run-20250201_105403-p1g9c549
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run apricot-totem-7
# wandb: ⭐️ View project at https://wandb.ai/sadwat/TLab-reinforce-with-baseline
# wandb: 🚀 View run at https://wandb.ai/sadwat/TLab-reinforce-with-baseline/runs/p1g9c549
# Device: cuda
# ...

# %%
# !zip -r "reinforce_with_baseline_v2.zip" "./reinforce_with_baseline_v2"
# Out:
#   adding: reinforce_with_baseline_v1/ (stored 0%)
#   adding: reinforce_with_baseline_v1/generation_config.json (deflated 30%)
#   adding: reinforce_with_baseline_v1/model.safetensors (deflated 7%)
#   adding: reinforce_with_baseline_v1/config.json (deflated 50%)

# %% [markdown]
# ## Level 2

# %% [markdown]
# ## Reward Model

# %%
# !python tlab-assignment/src/reward_model_trainer_2.py --output_model_dir=./trained_second_reward_model_v2
# Out:
# 2025-02-01 16:38:36.314808: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-01 16:38:36.508498: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-01 16:38:36.563452: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: sadwat. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# ...

# %%
# !zip -r "trained_second_reward_model_v2.zip" "./trained_second_reward_model_v2"

# %% [markdown]
# ## REINFORCE w/ baseline (r = E[reward])

# %%
# !python tlab-assignment/src/reinforce_2_expected.py --reward_model_path=./trained_second_reward_model_v2 --output_model_dir=./reinforce_2_expected_v3
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: sadwat. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.19.1
# wandb: Run data is saved locally in /kaggle/working/tlab-assignment/wandb/run-20250201_212221-cj6hh7lm
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run rural-night-11
# wandb: ⭐️ View project at https://wandb.ai/sadwat/TLab-reinforce-with-baseline
# wandb: 🚀 View run at https://wandb.ai/sadwat/TLab-reinforce-with-baseline/runs/cj6hh7lm
# Device: cuda
# ...

# %%
# !zip -r "reinforce_2_expected_v3.zip" "./reinforce_2_expected_v3"
# Out:
# updating: ../reinforce_2_expected_v3/ (stored 0%)
# updating: ../reinforce_2_expected_v3/model.safetensors (deflated 7%)
# updating: ../reinforce_2_expected_v3/config.json (deflated 50%)
# updating: ../reinforce_2_expected_v3/generation_config.json (deflated 30%)

# %% [markdown]
# ## Формула с дисперсией

# %%
# !python tlab-assignment/src/reinforce_2_variance.py --reward_model_path=./trained_second_reward_model_v2 --output_model_dir=./reinforce_2_variance_v2
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: sadwat. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.19.1
# wandb: Run data is saved locally in /kaggle/working/tlab-assignment/wandb/run-20250201_194816-az07z67g
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run magic-hill-9
# wandb: ⭐️ View project at https://wandb.ai/sadwat/TLab-reinforce-with-baseline
# wandb: 🚀 View run at https://wandb.ai/sadwat/TLab-reinforce-with-baseline/runs/az07z67g
# Device: cuda
# ...
